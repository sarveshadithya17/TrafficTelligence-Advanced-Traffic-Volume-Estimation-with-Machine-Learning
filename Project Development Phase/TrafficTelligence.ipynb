# %%
#importing necessary libraries

import pandas as pd
import numpy as np
import seaborn as sns
import sklearn as sk
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn import tree
from sklearn import ensemble
from sklearn import svm
from collections import Counter
import xgboost

# %%
#importing the data

data = pd.read_csv('traffic volume.csv')

# %%
#displaying first 5 rows of the data
data.head()
# Out:
#   holiday    temp  rain  snow weather        date      Time  traffic_volume
# 0    None  288.28   0.0   0.0  Clouds  02-10-2012  09:00:00            5545
# 1    None  289.36   0.0   0.0  Clouds  02-10-2012  10:00:00            4516
# 2    None  289.58   0.0   0.0  Clouds  02-10-2012  11:00:00            4767
# 3    None  290.13   0.0   0.0  Clouds  02-10-2012  12:00:00            5026
# 4    None  291.14   0.0   0.0  Clouds  02-10-2012  13:00:00            4918

# %%
#used to display the basic information of the data

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48204 entries, 0 to 48203
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   holiday         48204 non-null  object
#  1   temp            48151 non-null  float64
#  2   rain            48202 non-null  float64
#  3   snow            48192 non-null  float64
#  4   weather         48155 non-null  object
#  5   date            48204 non-null  object
#  6   Time            48204 non-null  object
#  7   traffic_volume  48204 non-null  int64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 2.9+ MB

# %%
# used to display the null values of the data

data.isnull().sum()
# Out:
# holiday            0
# temp              53
# rain               2
# snow              12
# weather           49
# date               0
# Time               0
# traffic_volume     0
# dtype: int64

# %%
data['temp'].fillna(data['temp'].mean(),inplace=True)
data['rain'].fillna(data['rain'].mean(),inplace=True)
data['snow'].fillna(data['snow'].mean(),inplace=True)

print(Counter(data['weather']))
# Out:
# Counter({'Clouds': 15144, 'Clear': 13383, 'Mist': 5942, 'Rain': 5665, 'Snow': 2875, 'Drizzle': 1818, 'Haze': 1359, 'Thunderstorm': 1033, 'Fog': 912, nan: 49, 'Smoke': 20, 'Squall': 4})

# %%
data['weather'].fillna('Clouds',inplace=True)

# %%
#splitting the date column into year,month,day
data[["day", "month", "year"]] = data["date"].str.split("-", expand = True)

# %%
#splitting the Time column into hour,minute,second
data[["hours", "minutes", "seconds"]] = data["Time"].str.split(":", expand = True)

# %%
data.drop(columns=['date','Time'],axis=1,inplace=True)

# %%
data.head()
# Out:
#   holiday    temp  rain  snow weather  traffic_volume day month  year hours  \
# 0    None  288.28   0.0   0.0  Clouds            5545  02    10  2012    09
# 1    None  289.36   0.0   0.0  Clouds            4516  02    10  2012    10
# 2    None  289.58   0.0   0.0  Clouds            4767  02    10  2012    11
# 3    None  290.13   0.0   0.0  Clouds            5026  02    10  2012    12
# 4    None  291.14   0.0   0.0  Clouds            4918  02    10  2012    13
#
#   minutes seconds
# 0      00      00
# 1      00      00
# 2      00      00
# 3      00      00
# 4      00      00

# %%
#used to understand the descriptive analysis of the data
data.describe()
# Out:
#                temp          rain          snow  traffic_volume
# count  48204.000000  48204.000000  48204.000000    48204.000000
# mean     281.205351      0.334278      0.000222     3259.818355
# std       13.336338     44.789133      0.008168     1986.860670
# min        0.000000      0.000000      0.000000        0.000000
# 25%      272.180000      0.000000      0.000000     1193.000000
# 50%      282.429000      0.000000      0.000000     3380.000000
# 75%      291.800000      0.000000      0.000000     4933.000000
# max      310.070000   9831.300000      0.510000     7280.000000

# %%
# Import label encoder 
from sklearn import preprocessing 
  
# label_encoder object knows  
# how to understand word labels. 
label_encoder = preprocessing.LabelEncoder()

# %%
data['holiday_v2'] = label_encoder.fit_transform(data['holiday'])

# %%
data['weather_v2']= label_encoder.fit_transform(data['weather']) 
print(label_encoder.classes_)
data['weather_v2'].unique()
# Out:
# ['Clear' 'Clouds' 'Drizzle' 'Fog' 'Haze' 'Mist' 'Rain' 'Smoke' 'Snow'
#  'Squall' 'Thunderstorm']
# array([ 1,  0,  6,  2,  5,  4,  3, 10,  8,  9,  7])

# %%
cor = data.corr()
cor
# Out:
#                     temp      rain      snow  traffic_volume  holiday_v2  \
# temp            1.000000  0.009070 -0.019758        0.130034   -0.000472
# rain            0.009070  1.000000 -0.000090        0.004714    0.000066
# snow           -0.019758 -0.000090  1.000000        0.000735    0.000432
# traffic_volume  0.130034  0.004714  0.000735        1.000000    0.018676
# holiday_v2     -0.000472  0.000066  0.000432        0.018676    1.000000
# weather_v2     -0.033559  0.009542  0.036662       -0.040035   -0.004328
#
#                 weather_v2
# temp             -0.033559
# rain              0.009542
# snow              0.036662
# traffic_volume   -0.040035
# holiday_v2       -0.004328
# weather_v2        1.000000

# %%
sns.heatmap(cor)
# Out:
# <AxesSubplot:>

# %%
sns.countplot(data['weather'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='weather', ylabel='count'>

# %%
sns.countplot(data['holiday_v2'],hue=data['weather_v2'])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(data)

# %%
data.boxplot()
# Out:
# <AxesSubplot:>

# %%
y = data['traffic_volume']
x = data.drop(columns=['traffic_volume','holiday','weather'],axis=1)

# %%
names = x.columns

# %%
from sklearn.preprocessing import scale

# %%
x = scale(x)

# %%
x = pd.DataFrame(x,columns=names)

# %%
x.head()
# Out:
#        temp      rain      snow       day    month      year     hours  \
# 0  0.530485 -0.007463 -0.027235 -1.574903  1.02758 -1.855294 -0.345548
# 1  0.611467 -0.007463 -0.027235 -1.574903  1.02758 -1.855294 -0.201459
# 2  0.627964 -0.007463 -0.027235 -1.574903  1.02758 -1.855294 -0.057371
# 3  0.669205 -0.007463 -0.027235 -1.574903  1.02758 -1.855294  0.086718
# 4  0.744939 -0.007463 -0.027235 -1.574903  1.02758 -1.855294  0.230807
#
#    minutes  seconds  holiday_v2  weather_v2
# 0      0.0      0.0    0.015856   -0.566452
# 1      0.0      0.0    0.015856   -0.566452
# 2      0.0      0.0    0.015856   -0.566452
# 3      0.0      0.0    0.015856   -0.566452
# 4      0.0      0.0    0.015856   -0.566452

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
#Model Building
from sklearn import linear_model
from sklearn import tree
from sklearn import ensemble
from sklearn import svm
import xgboost

# %%
lin_reg = linear_model.LinearRegression()
Dtree = tree.DecisionTreeRegressor()
Rand = ensemble.RandomForestRegressor()
svr = svm.SVR()
XGB = xgboost.XGBRegressor()

# %%
lin_reg.fit(x_train,y_train)
Dtree.fit(x_train,y_train)
Rand.fit(x_train,y_train)
svr.fit(x_train,y_train)
XGB.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
p1 = lin_reg.predict(x_train)
p2 = Dtree.predict(x_train)
p3 = Rand.predict(x_train)
p4 = svr.predict(x_train)
p5 = XGB.predict(x_train)

# %%
#Testing the model
#1.using R-squared_score
from sklearn.metrics import r2_score
p1 = lin_reg.predict(x_test)
print(r2_score(p1,y_test))
# Out:
# -5.399396398322184

# %%
p2 = Dtree.predict(x_test)
print(r2_score(p2,y_test))
# Out:
# 0.6930052870641763

# %%
p3 = Rand.predict(x_test)
print(r2_score(p3,y_test))
# Out:
# 0.804032794847801

# %%
p4 = svr.predict(x_test)
print(r2_score(p4,y_test))
# Out:
# -11.972215715232434

# %%
p5 = XGB.predict(x_test)
print(r2_score(p5,y_test))
# Out:
# 0.8066516776309793

# %%
#2.Using Root mean squared error(RMSE)
from sklearn import metrics

# %%
MSE = metrics.mean_squared_error(p1,y_test)
np.sqrt(MSE)
# Out:
# 1838.3976719006828

# %%
MSE = metrics.mean_squared_error(p2,y_test)
np.sqrt(MSE)
# Out:
# 1097.460402156461

# %%
MSE = metrics.mean_squared_error(p3,y_test)
np.sqrt(MSE) #Less compared to others
# Out:
# 797.1141248467267

# %%
MSE = metrics.mean_squared_error(p4,y_test)
np.sqrt(MSE)
# Out:
# 1715.2770939066922

# %%
MSE = metrics.mean_squared_error(p5,y_test)
np.sqrt(MSE)
# Out:
# 794.8443863964126

# %% [raw]
# RMSD value for Random forest is very less when compared with other models,so
# saving the Random forest model and deploying using the following process

# %%
#Model Deployment
#saving the model
import pickle
from sklearn.preprocessing import LabelEncoder
le = le = LabelEncoder()
pickle.dump(Rand, open("model.pkl",'wb'))
pickle.dump(le, open("encoder.pkl", "wb"))
